# %% [markdown]
# The purpose of this notebook is to track the progress of reprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import utilix
import numpy as np
from tqdm import tqdm
import os
path_start = '/dali/lgrandi/rucio/xnt_'

# %%
def find_with_mode(rules, runs, mode):
    is_mode = np.zeros(len(rules), np.bool)
    for i,r in enumerate(rules):
        if int(r['runid'])<50126:
            if runs[int(r['runid'])]['mode'] == mode:
                is_mode[i] = True
    print(np.sum(is_mode))
    return rules[is_mode]

def size_vs_runs(rules, runid_min=0, runid_max=50200, nbins=100):
    runids = rules['runid'].astype(np.int32)
    bins_bound = np.linspace(runid_min, runid_max, nbins+1)
    sizes_tb = np.zeros(nbins)
    for b in range(nbins):
        selected_mask = runids>=bins_bound[b]
        selected_mask &= runids<=bins_bound[b+1]
        rules_selected = rules[selected_mask]
        if len(rules_selected):
            sizes_tb[b] = np.sum(rules_selected['size_gb']/1024)
    
    cum_sizes_tb = np.cumsum(sizes_tb)
    return cum_sizes_tb

def find_with_tags(rules, runs, tags):
    tagged = np.zeros(len(rules), np.bool)
    for i,r in enumerate(rules):
        for t in tags:
            if runs[int(r['runid'])][t]:
                tagged[i] = True
    print(np.sum(tagged))
    return rules[tagged]

def filter_out_rad(rules, runs):
    is_rad = np.zeros(len(rules), np.bool)
    for i,r in enumerate(rules):
        if runs[int(r['runid'])]['RAD_commissioning']:
            is_rad[i] = True
    return rules[~is_rad]

# %%
import pymongo
from utilix import xent_collection
coll = xent_collection()

runs_dtype = np.dtype([('number', np.int32), 
                       ('mode', 'O'),
                       ('bad', np.bool),
                       ('messy', np.bool),
                       ('hot_spot', np.bool),
                       ('ramp_down', np.bool),
                       ('ramp_up', np.bool),
                       ('pmt_trip', np.bool),
                       ('rn220_fast_alphas', np.bool),
                       ('after_rn220', np.bool),
                       ('abandon', np.bool),
                       ('RAD_commissioning', np.bool)])
runs = np.zeros(50126, dtype = runs_dtype)

for i in tqdm(range(50126)):
    query = {'number': i}
    doc = coll.find_one(query)
    runs[i]['number'] = i
    runs[i]['mode'] = doc['mode']
    try:
        tags = doc['tags']
        for t in tags:
            if t['name'] == 'bad':
                runs[i]['bad'] = True
            elif t['name'] == 'messy':
                runs[i]['messy'] = True
            elif t['name'] == 'hot_spot':
                runs[i]['hot_spot'] = True
            elif t['name'] == 'ramp_down':
                runs[i]['ramp_down'] = True
            elif t['name'] == 'ramp_up':
                runs[i]['ramp_up'] = True            
            elif t['name'] == 'pmt_trip':
                runs[i]['pmt_trip'] = True
            elif t['name'] == 'rn220_fast_alphas':
                runs[i]['rn220_fast_alphas'] = True
            elif t['name'] == 'after_rn220':
                runs[i]['after_rn220'] = True
            elif t['name'] == 'abandon':
                runs[i]['abandon'] = True
            elif t['name'] == 'RAD_commissioning' or (i in radon_presr0):
                runs[i]['RAD_commissioning'] = True
    except:
        pass
# Out:
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('bad', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('messy', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('hot_spot', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('ramp_down', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('ramp_up', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('pmt_trip', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('rn220_fast_alphas', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('after_rn220', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('abandon', np.bool),
# /tmp/jobs/26078791/ipykernel_114/1859552947.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('RAD_commissioning', np.bool)])
# 100%|██████████| 50126/50126 [02:59<00:00, 279.96it/s]

# %%
for i in range(20):
    if i == 0:
        rules_info = np.load('/project2/lgrandi/yuanlq/shared/dali_cleanup/rucio_20230113_all_rules0.npy', 
                             allow_pickle=True)
    else:
        new = np.load('/project2/lgrandi/yuanlq/shared/dali_cleanup/rucio_20230113_all_rules%s.npy'%(i), 
                      allow_pickle=True)
        rules_info = np.concatenate((rules_info, new))

# %%
sr0_right = 34731
sr0_left  = 17918
sr1_left  = 43039
sr1_right = 50200

# %%
rules_info = rules_info[rules_info['UC_DALI_USERDISK']]

# %%
rules_info = rules_info[rules_info['runid'].astype(int)<50126]
rules_info_norad = filter_out_rad(rules=rules_info, runs=runs)
# Out:
# /tmp/jobs/26078791/ipykernel_114/1901956045.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   is_rad = np.zeros(len(rules), np.bool)

# %%
size_all = rules_info['size_gb'].sum()
print('All rucio data on dali: %sTB'%(int(size_all/1024)))
# Out:
# All rucio data on dali: 154TB

# %%
size_peaklets = rules_info['size_gb'][rules_info['data_type']=='peaklets'].sum()
print('All peaklets on dali: %sTB'%(int(size_peaklets/1024)))
# Out:
# All peaklets on dali: 78TB

# %%
size_hitlets_nv = rules_info['size_gb'][rules_info['data_type']=='hitlets_nv'].sum()
print('All hitlets_nv on dali: %sTB'%(int(size_hitlets_nv/1024)))
# Out:
# All hitlets_nv on dali: 35TB

# %%
rules_info['size_gb'].sum() - \
rules_info['size_gb'][rules_info['data_type']=='peaklets'].sum() - \
rules_info['size_gb'][rules_info['data_type']=='hitlets_nv'].sum() - rules_info['size_gb'][rules_info['data_type']=='merged_s2s'].sum()

# %%
all_dtypes = np.unique(rules_info['data_type'])
names = []
sizes_gb = []
for dt in all_dtypes:
    selected = rules_info[rules_info['data_type']==dt]
    names.append(dt)
    sizes_gb.append(selected['size_gb'].sum())
names = np.array(names)
sizes_gb = np.array(sizes_gb)
argsort = sizes_gb.argsort()
names_sort = names[argsort]
sizes_gb_sort = sizes_gb[argsort]
for i in range(len(names)):
    if int(sizes_gb_sort[i]/1024) >= 1:
        print(names_sort[i], int(sizes_gb_sort[i]/1024), 'TB')

# %%
cum_sizes_tb_pkl = size_vs_runs(rules_info_norad[rules_info_norad['data_type']=='peaklets'])
cum_sizes_tb_hnv = size_vs_runs(rules_info_norad[rules_info_norad['data_type']=='hitlets_nv'])
cum_sizes_tb_ms2 = size_vs_runs(rules_info_norad[rules_info_norad['data_type']=='merged_s2s'])

# %%
plt.figure(dpi=100)
plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_pkl, label='peaklets')
plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_hnv, label='hitlets_nv')
plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_ms2, label='merged_s2s')

plt.xlabel('RunID')
plt.title('DaLI Top 3 Datatype')
plt.ylabel('Size [TB]')
plt.axvspan(sr0_left, sr0_right, alpha=0.3, color='k', label='SR0')
plt.axvspan(sr1_left, sr1_right, alpha=0.3, color='r', label='SR1')
#plt.yscale('log')
plt.gca().set_ylim(top=80)
plt.legend()

# %%
import cutax
st = cutax.contexts.xenonnt_online()
all_runs = st.select_runs()
modes = set(all_runs["mode"])
modes_list = list(modes)

# %%
total_pkl = 0

size_pkl = []

for m in modes_list:
    rules_info_mode = find_with_mode(rules=rules_info_norad, runs=runs, mode=m)
    cum_sizes_tb_pkl_mode = size_vs_runs(rules_info_mode[(rules_info_mode['data_type']=='peaklets')])
        
    total_pkl += cum_sizes_tb_pkl_mode[-1]
    
    size_pkl.append(int(cum_sizes_tb_pkl_mode[-1]))
    
    if cum_sizes_tb_pkl_mode[-1] > 0.2: 
    
        plt.figure(dpi=100)
        plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_pkl_mode, label='peaklets')
        plt.xlabel('RunID')
        plt.title('Mode %s'%(m))
        plt.ylabel('Size [TB]')
        plt.axvspan(sr0_left, sr0_right, alpha=0.3, color='k', label='SR0')
        plt.axvspan(sr1_left, sr1_right, alpha=0.3, color='r', label='SR1')
        #plt.yscale('log')
        #plt.gca().set_ylim(bottom=1)
        plt.legend()
        plt.savefig('osg_straxdata_mode_%s'%(m))
        plt.show()

size_pkl = np.array(size_pkl)   

modes_list = np.array(modes_list)

for i in range(len(modes_list)):
    if size_pkl[size_pkl.argsort()][i] > 0.2:
        print(modes_list[size_pkl.argsort()][i], size_pkl[size_pkl.argsort()][i], 'TB')

# %%
total_ms2 = 0

size_ms2 = []

for m in modes_list:
    rules_info_mode = find_with_mode(rules=rules_info_norad, runs=runs, mode=m)
    cum_sizes_tb_ms2_mode = size_vs_runs(rules_info_mode[(rules_info_mode['data_type']=='merged_s2s')])
        
    total_ms2 += cum_sizes_tb_ms2_mode[-1]
    
    size_ms2.append(int(cum_sizes_tb_ms2_mode[-1]))
    
    if cum_sizes_tb_ms2_mode[-1] > 0.2: 
    
        plt.figure(dpi=100)
        plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_ms2_mode, label='merged_s2s')
        plt.xlabel('RunID')
        plt.title('Mode %s'%(m))
        plt.ylabel('Size [TB]')
        plt.axvspan(sr0_left, sr0_right, alpha=0.3, color='k', label='SR0')
        plt.axvspan(sr1_left, sr1_right, alpha=0.3, color='r', label='SR1')
        #plt.yscale('log')
        #plt.gca().set_ylim(bottom=1)
        plt.legend()
        plt.savefig('osg_straxdata_mode_%s'%(m))
        plt.show()

size_ms2 = np.array(size_ms2)   

modes_list = np.array(modes_list)

for i in range(len(modes_list)):
    if size_ms2[size_ms2.argsort()][i] > 0.2:
        print(modes_list[size_ms2.argsort()][i], size_ms2[size_ms2.argsort()][i], 'TB')

# %%
total_rrnv = 0

size_rrnv = []

for m in modes_list:
    rules_info_mode = find_with_mode(rules=rules_info_norad, runs=runs, mode=m)
    cum_sizes_tb_rrnv_mode = size_vs_runs(rules_info_mode[(rules_info_mode['data_type']=='hitlets_nv')])
        
    total_rrnv += cum_sizes_tb_rrnv_mode[-1]
    
    size_rrnv.append(int(cum_sizes_tb_rrnv_mode[-1]))
    
    if cum_sizes_tb_rrnv_mode[-1] > 0.2: 
    
        plt.figure(dpi=100)
        plt.plot(np.linspace(0, 50200, 100), cum_sizes_tb_rrnv_mode, label='hitlets_nv')
        plt.xlabel('RunID')
        plt.title('Mode %s'%(m))
        plt.ylabel('Size [TB]')
        plt.axvspan(sr0_left, sr0_right, alpha=0.3, color='k', label='SR0')
        plt.axvspan(sr1_left, sr1_right, alpha=0.3, color='r', label='SR1')
        #plt.yscale('log')
        #plt.gca().set_ylim(bottom=1)
        plt.legend()
        plt.savefig('osg_straxdata_mode_%s'%(m))
        plt.show()

size_rrnv = np.array(size_rrnv)   

modes_list = np.array(modes_list)

for i in range(len(modes_list)):
    if size_rrnv[size_rrnv.argsort()][i] > 0.2:
        print(modes_list[size_rrnv.argsort()][i], size_rrnv[size_rrnv.argsort()][i], 'TB')

# %%
rules_info_lowq = find_with_tags(rules=rules_info, runs=runs, tags=['bad', 'messy', 'abandon',
                                                                    'ramp_down', 'ramp_up',
                                                                    'pmt_trip', 'rn220_fast_alphas',
                                                                    'after_rn220', 'abandon'])

# %%
np.sum(rules_info_lowq['size_gb'])

# %%
cum_sizes_tb_pkl = size_vs_runs(rules_info_norad[rules_info_norad['data_type']=='peaklets'])

# %%
#np.save('delete_dali_20230216/low_quality_data.npy', rules_info_lowq)

# %% [markdown]
# # Find Duplicate Outdated

# %%
len(rules_info)
# Out:
# 805014

# %%
import utilix
import pandas as pd

pd.DataFrame(
    utilix.rundb.xent_collection(collection='contexts').find(
    {'hashes.peaklets' :'wfhfmcbq5z'})
)

# %% [markdown]
# Logic:
# - Loop over datatype for a certain run:
#     - check if this guy has an older version.

# %%
peaklets = rules_info[rules_info['data_type']=='peaklets']
hitlets_nv = rules_info[rules_info['data_type']=='hitlets_nv']
merged_s2s = rules_info[rules_info['data_type']=='merged_s2s']
lone_hits = rules_info[rules_info['data_type']=='lone_hits']
peak_basics = rules_info[rules_info['data_type']=='peak_basics']

# %%
type(pd.DataFrame(
    utilix.rundb.xent_collection(collection='contexts').find(
    {'hashes.peaklets' :'wfhfmcbq5z'})
).straxen_version)
# Out:
# pandas.core.series.Series

# %%
from tqdm import tqdm
def determine_context(rules_info, dtype='peaklets'):
    contexts = []
    for rule in tqdm(rules_info):
        p = pd.DataFrame(
            utilix.rundb.xent_collection(collection='contexts').find(
            {'hashes.%s'%(dtype) :rule['hash']})
            )
        try:
            names = p.straxen_version
            contexts.append(names.max())
        except:
            contexts.append('0.0.0')
    return contexts

# %%
pd.DataFrame(
            utilix.rundb.xent_collection(collection='contexts').find(
            {'hashes.%s'%('merged_s2s') :'f3qbwvvh2w'})
            )

# %%
merged_s2s['hash']

# %%
peaklets_contexts = determine_context(rules_info=peaklets, dtype='peaklets')
# Out:
# 100%|██████████| 25614/25614 [02:54<00:00, 146.63it/s]

# %%
lone_hits_contexts = determine_context(rules_info=lone_hits, dtype='lone_hits')
# Out:
# 100%|██████████| 22571/22571 [02:37<00:00, 143.74it/s]

# %%
peak_basics_contexts = determine_context(rules_info=peak_basics, dtype='peak_basics')
# Out:
# 100%|██████████| 28395/28395 [03:35<00:00, 131.95it/s]

# %%
merged_s2s_contexts = determine_context(rules_info=merged_s2s, dtype='merged_s2s')
# Out:
# 100%|██████████| 17205/17205 [02:21<00:00, 121.98it/s]

# %%
hitlets_nv_contexts = determine_context(rules_info=hitlets_nv, dtype='hitlets_nv')
# Out:
# 100%|██████████| 25544/25544 [03:01<00:00, 140.48it/s]

# %% [markdown]
# For peaklets, if there is a lower version, delete that one.

# %%
peaklets['runid']

# %%
peaklets_redundant_mask = np.zeros(len(peaklets), dtype=np.bool)
peaklets_to_delete = []
peaklets_contexts = np.array(peaklets_contexts)
for i,rule in tqdm(enumerate(peaklets)):
    same_run_mask = peaklets['runid']==rule['runid']
    contexts = peaklets_contexts[same_run_mask]
    if peaklets_contexts[i] != np.max(pd.Series(contexts)):
        peaklets_to_delete.append(rule)
peaklets_to_delete = np.array(peaklets_to_delete)

# %%
lone_hits_redundant_mask = np.zeros(len(lone_hits), dtype=np.bool)
lone_hits_to_delete = []
lone_hits_contexts = np.array(lone_hits_contexts)
for i,rule in tqdm(enumerate(lone_hits)):
    same_run_mask = lone_hits['runid']==rule['runid']
    contexts = lone_hits_contexts[same_run_mask]
    if lone_hits_contexts[i] != np.max(pd.Series(contexts)):
        lone_hits_to_delete.append(rule)
lone_hits_to_delete = np.array(lone_hits_to_delete)

# %%
len(peaklets_to_delete)

# %%
len(peaklets)

# %%
peaklets['size_gb'].sum()

# %%
peaklets_to_delete['size_gb'].sum()

# %%
np.save('delete_dali_20230216/duplicated_peaklets.npy', peaklets_to_delete)

# %%
np.save('delete_dali_20230216/duplicated_lone_hits.npy', lone_hits_to_delete)

# %%
plt.hist(peaklets['runid'].astype(int), bins=np.linspace(12000,50000,100), label='All rules')
plt.hist(peaklets_to_delete['runid'].astype(int), bins=np.linspace(12000,50000,100), label='Outdated rules')
plt.xlabel('RunID')
plt.legend()
plt.title('peaklets on DaLI')
plt.ylabel('Counts')

# %%
plt.hist(lone_hits['runid'].astype(int), bins=np.linspace(12000,50000,100), label='All rules')
plt.hist(lone_hits_to_delete['runid'].astype(int), bins=np.linspace(12000,50000,100), label='Outdated rules')
plt.xlabel('RunID')
plt.legend()
plt.title('lone_hits on DaLI')
plt.ylabel('Counts')

# %%
lone_hits_to_delete['size_gb'].sum()

# %%
merged_s2s_to_delete = merged_s2s[merged_s2s['hash']=='xlkyjhsuda']

# %%
np.sum(merged_s2s_to_delete['size_gb'])

# %%
np.save('delete_dali_20230216/duplicated_merged_s2s.npy', merged_s2s_to_delete)

# %%
#v3 and v7
hitlets_nv_to_delete = hitlets_nv[(hitlets_nv['hash']=='jg5y7hv3iq')|(hitlets_nv['hash']=='w2vwlxy2wh')]

# %%
np.sum(hitlets_nv_to_delete['size_gb'])

# %%
np.save('delete_dali_20230216/duplicated_hitlets_nv.npy', hitlets_nv_to_delete)

# %%
peaklets_to_delete = np.load('delete_dali_20230216/duplicated_peaklets.npy', allow_pickle=True)

# %%
hitlets_nv_to_delete = np.load('delete_dali_20230216/duplicated_hitlets_nv.npy', allow_pickle=True)

# %%
lone_hits_to_delete = np.load('delete_dali_20230216/duplicated_lone_hits.npy', allow_pickle=True)

# %%
np.unique(peaklets_to_delete['hash'])
# Out:
# array(['6et4xh7yqh', 'az7dbwq5pl', 'gwiwppglt4', 'pvdcwix5ar',
#        'siob2wxxm5', 'wfhfmcbq5z'], dtype=object)

# %%
np.unique(lone_hits_to_delete['hash'])
# Out:
# array(['gwiwppglt4', 'pvdcwix5ar', 'q3fr7osh7u', 'siob2wxxm5',
#        'uhfusstvab', 'wfhfmcbq5z'], dtype=object)

# %%
np.unique(hitlets_nv_to_delete['hash'])
# Out:
# array(['jg5y7hv3iq', 'w2vwlxy2wh'], dtype=object)

# %%
v8_like_peaklets = peaklets_to_delete[peaklets_to_delete['hash']=='siob2wxxm5']['runid']
v8_like_lonehits = lone_hits_to_delete[lone_hits_to_delete['hash']=='siob2wxxm5']['runid']

# %%
outdated = []

for runid in v8_like_lonehits:
    selected = lone_hits[(lone_hits['hash']!='siob2wxxm5') & (lone_hits['runid']==runid)]
    print(runid, selected['hash'])
# Out:
# 018159 ['pvdcwix5ar' 'xl4tm6igvz']
# 018253 ['pvdcwix5ar' 'xl4tm6igvz']
# 018362 ['pvdcwix5ar' 'xl4tm6igvz']
# 018415 ['pvdcwix5ar' 'xl4tm6igvz']
# 018483 ['pvdcwix5ar' 'xl4tm6igvz']
# 018548 ['pvdcwix5ar' 'xl4tm6igvz']
# 018604 ['pvdcwix5ar' 'xl4tm6igvz']
# 018660 ['pvdcwix5ar' 'xl4tm6igvz']
# 018705 ['pvdcwix5ar' 'xl4tm6igvz']
# 018761 ['pvdcwix5ar' 'xl4tm6igvz']
# 018812 ['pvdcwix5ar' 'xl4tm6igvz']
# 018867 ['pvdcwix5ar' 'xl4tm6igvz']
# 018947 ['pvdcwix5ar' 'xl4tm6igvz']
# 019150 ['pvdcwix5ar' 'xl4tm6igvz']
# 019227 ['pvdcwix5ar' 'xl4tm6igvz']
# 019769 ['pvdcwix5ar' 'xl4tm6igvz']
# 019820 ['pvdcwix5ar' 'xl4tm6igvz']
# 019997 ['pvdcwix5ar' 'xl4tm6igvz']
# 020045 ['pvdcwix5ar' 'xl4tm6igvz']
# 020087 ['pvdcwix5ar' 'xl4tm6igvz']
# 020138 ['pvdcwix5ar' 'xl4tm6igvz']
# 021509 ['pvdcwix5ar' 'xl4tm6igvz']
# 021743 ['pvdcwix5ar' 'xl4tm6igvz']
# 021993 ['pvdcwix5ar' 'xl4tm6igvz']
# 022058 ['pvdcwix5ar' 'xl4tm6igvz']
# 022228 ['pvdcwix5ar' 'xl4tm6igvz']
# 022354 ['pvdcwix5ar' 'xl4tm6igvz']
# 022477 ['pvdcwix5ar' 'xl4tm6igvz']
# 022543 ['pvdcwix5ar' 'xl4tm6igvz']
# 022676 ['pvdcwix5ar' 'xl4tm6igvz']
# 022797 ['pvdcwix5ar' 'xl4tm6igvz']
# 023274 ['pvdcwix5ar' 'xl4tm6igvz']
# 023467 ['pvdcwix5ar' 'xl4tm6igvz']
# 023549 ['pvdcwix5ar' 'xl4tm6igvz']
# 023710 ['pvdcwix5ar' 'xl4tm6igvz']
# 011975 ['xl4tm6igvz']
# 011976 ['xl4tm6igvz']
# 011978 ['xl4tm6igvz']
# 011979 ['xl4tm6igvz']
# 011982 ['xl4tm6igvz']
# 011984 ['xl4tm6igvz']
# 011985 ['xl4tm6igvz']
# 011995 ['xl4tm6igvz']
# 011997 ['xl4tm6igvz']
# 011999 ['xl4tm6igvz']
# 012000 ['xl4tm6igvz']
# 012001 ['xl4tm6igvz']
# 012003 ['xl4tm6igvz']
# 012006 ['xl4tm6igvz']
# 012007 ['xl4tm6igvz']
# 012008 ['xl4tm6igvz']
# 012010 ['xl4tm6igvz']
# 012011 ['xl4tm6igvz']
# 012014 ['xl4tm6igvz']
# 012015 ['xl4tm6igvz']
# 012017 ['xl4tm6igvz']
# 012039 ['xl4tm6igvz']
# 012052 ['xl4tm6igvz']
# 012061 ['xl4tm6igvz']
# 018159 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018253 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018362 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018415 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018483 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018548 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018604 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018660 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018705 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018761 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018812 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018867 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 018947 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 019150 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 019227 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 019769 ['pvdcwix5ar' 'xl4tm6igvz']
# 019820 ['pvdcwix5ar' 'xl4tm6igvz']
# 019997 ['pvdcwix5ar' 'xl4tm6igvz']
# 020045 ['pvdcwix5ar' 'xl4tm6igvz']
# 020087 ['pvdcwix5ar' 'xl4tm6igvz']
# 020138 ['pvdcwix5ar' 'xl4tm6igvz']
# 021509 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 021743 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 021993 ['pvdcwix5ar' 'xl4tm6igvz']
# 022058 ['pvdcwix5ar' 'xl4tm6igvz']
# 022228 ['pvdcwix5ar' 'xl4tm6igvz']
# 022354 ['pvdcwix5ar' 'xl4tm6igvz']
# 022477 ['pvdcwix5ar' 'xl4tm6igvz']
# 022543 ['pvdcwix5ar' 'xl4tm6igvz']
# 022676 ['pvdcwix5ar' 'xl4tm6igvz']
# 022797 ['pvdcwix5ar' 'xl4tm6igvz']
# 023274 ['pvdcwix5ar' 'xl4tm6igvz']
# 023467 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 023549 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 023710 ['pvdcwix5ar' 'xl4tm6igvz']
# 023831 ['pvdcwix5ar' 'xl4tm6igvz']
# 023988 ['pvdcwix5ar' 'xl4tm6igvz']
# 024399 ['6et4xh7yqh' 'pvdcwix5ar' 'xl4tm6igvz']
# 026102 ['6et4xh7yqh' 'xl4tm6igvz']
# 027031 ['6et4xh7yqh' 'xl4tm6igvz']
# 028653 ['6et4xh7yqh' 'xl4tm6igvz']
# 029521 ['6et4xh7yqh' 'xl4tm6igvz']
# 030400 ['6et4xh7yqh' 'xl4tm6igvz']
# 030475 ['6et4xh7yqh' 'xl4tm6igvz']
# 030550 ['6et4xh7yqh' 'xl4tm6igvz']
# 031843 ['6et4xh7yqh' 'xl4tm6igvz']
# 031918 ['6et4xh7yqh' 'xl4tm6igvz']
# 033226 ['6et4xh7yqh' 'xl4tm6igvz']
# 033466 ['6et4xh7yqh' 'xl4tm6igvz']
# 033534 ['6et4xh7yqh' 'xl4tm6igvz']
# 033745 ['6et4xh7yqh' 'xl4tm6igvz']
# 033808 ['6et4xh7yqh' 'xl4tm6igvz']
# 033959 ['6et4xh7yqh' 'xl4tm6igvz']
# 034019 ['6et4xh7yqh' 'xl4tm6igvz']
['wfhfmcbq5z' 'xl4tm6igvz']
# 044555 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044556 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044557 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044558 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044559 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044560 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044561 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044563 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044569 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044570 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044573 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044576 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044577 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044578 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044580 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044581 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044582 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044584 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044585 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044586 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044587 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044588 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044589 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044590 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044591 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044592 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044594 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044595 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044596 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044597 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044598 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044599 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044600 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044601 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044602 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044822 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044823 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044824 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044825 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044826 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044827 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044828 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044829 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044830 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044831 ['wfhfmcbq5z' 'xl4tm6igvz']
# 044832 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 044833 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045180 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045181 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045186 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045189 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045190 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045192 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045193 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045195 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045196 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045197 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045198 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045199 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045200 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045201 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045206 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045207 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045208 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045209 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045210 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045211 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045213 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045214 ['jgo4lftayb' 'wfhfmcbq5z']
# 045215 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045216 ['jgo4lftayb' 'wfhfmcbq5z']
# 045217 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045218 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045219 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045223 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045224 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045225 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045226 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045227 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045229 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045233 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045234 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045235 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045236 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045237 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045240 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045241 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045245 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045247 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045248 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045249 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045250 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045251 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045252 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045254 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045255 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045257 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045258 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045259 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045260 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045261 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045262 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045263 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045264 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045265 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045267 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045268 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045270 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045271 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045272 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045273 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045274 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045275 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045276 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045277 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045278 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045279 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045280 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045281 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045283 ['wfhfmcbq5z' 'xl4tm6igvz']
# 045284 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045285 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045286 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045287 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045288 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045289 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045290 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045291 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045292 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045293 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045295 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045296 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045297 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045298 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045299 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045300 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045302 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045303 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045304 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045308 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045309 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045310 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045311 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045312 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045313 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045314 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045315 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045317 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045318 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045319 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045321 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045322 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045323 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045326 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045327 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045328 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045331 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045332 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045333 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045334 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045335 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045336 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045337 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045339 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045340 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045341 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045343 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045344 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045345 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045367 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045368 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045370 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045371 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045372 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045373 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045374 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045375 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045406 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045407 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045408 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045409 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045412 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045413 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045420 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045421 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045422 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045425 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045426 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045430 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045433 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045440 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045463 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045464 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045465 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045467 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045468 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045469 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045470 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045471 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045472 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045473 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045474 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045475 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045476 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045477 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045478 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045479 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045480 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045481 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045483 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045485 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045486 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045487 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045488 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045489 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045491 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045492 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045493 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045494 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']
# 045497 ['jgo4lftayb' 'wfhfmcbq5z' 'xl4tm6igvz']

# %%
sr0_left
# Out:
# 17918

# %%
sr0_right
# Out:
# 34731

# %% [markdown]
# We must keep v8 peaklets and lone_hits ("siob2wxxm5") for SR0! Excluding these guys from the list.

# %%
peaklets_to_delete = peaklets_to_delete[~((peaklets_to_delete['runid'].astype(int)<=sr0_right)
                      &(peaklets_to_delete['runid'].astype(int)>=sr0_left)
                      &(peaklets_to_delete['hash']=='siob2wxxm5'))]

# %%
lone_hits_to_delete = lone_hits_to_delete[~((lone_hits_to_delete['runid'].astype(int)<=sr0_right)
                      &(lone_hits_to_delete['runid'].astype(int)>=sr0_left)
                      &(lone_hits_to_delete['hash']=='siob2wxxm5'))]

# %%
peaklets_to_delete['size_gb'].sum()
# Out:
# 21085.64

# %%
lone_hits_to_delete['size_gb'].sum()
# Out:
# 1996.166

# %%
peaklets_to_delete['size_gb'].sum()
# Out:
# 21267.469

# %%
lone_hits_to_delete['size_gb'].sum()
# Out:
# 2032.3486

# %%
np.save('delete_dali_20230216/duplicated_peaklets.npy', peaklets_to_delete)

# %%
# After
